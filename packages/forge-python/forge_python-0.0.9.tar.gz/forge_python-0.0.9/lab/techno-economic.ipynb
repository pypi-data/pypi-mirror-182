# %%
pip install forge-python==0.0.8
# Out:
# Collecting forge-python==0.0.8
#   Downloading forge_python-0.0.8-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: numpy>=1.20.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from forge-python==0.0.8) (1.23.5)
# Requirement already satisfied: pandas>=1.2.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from forge-python==0.0.8) (1.5.2)
# Requirement already satisfied: requests>=2.25.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from forge-python==0.0.8) (2.28.1)
# Requirement already satisfied: rich>=9.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from forge-python==0.0.8) (12.6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.2.3->forge-python==0.0.8) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.2.3->forge-python==0.0.8) (2022.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.25.1->forge-python==0.0.8) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.25.1->forge-python==0.0.8) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.25.1->forge-python==0.0.8) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.25.1->forge-python==0.0.8) (2022.9.24)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich>=9.11.0->forge-python==0.0.8) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich>=9.11.0->forge-python==0.0.8) (2.13.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.3->forge-python==0.0.8) (1.16.0)
# Installing collected packages: forge-python
#   Attempting uninstall: forge-python
#     Found existing installation: forge-python 0.0.7
#     Uninstalling forge-python-0.0.7:
#       Successfully uninstalled forge-python-0.0.7
# Successfully installed forge-python-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
from forge_python import forge
sensor = forge.sensor()
sensor.authenticate("d1805592-64d8-4b70-8420-65276da5e37c")
sensor.send({'temperature': 95.5})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from forge_python import forge
#       2 sensor = forge.sensor()
#       3 sensor.authenticate("d1805592-64d8-4b70-8420-65276da5e37c")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/forge_python/forge.py:6
#       4 import time
#       5 import numpy as np
# ----> 6 from metrics import load_metrics
#       7 from rich.console import Console
#       9 console = Console()
#
# ModuleNotFoundError: No module named 'metrics'
